# %%
import  requests
from bs4 import BeautifulSoup

r=requests.get("https://www.century21.com/real-estate/cupertino-ca/LCCACUPERTINO/")
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"property-card-primary-info"})

all[0].find("a",{"class":"listing-price"}).text.replace("\n","").replace(" ","")
# Out:
# '$215,000'

# %%
l=[]
for item in all:
    d={}
    d["Address"]=item.find("div",{"class":"property-address-info"}).text.replace("\n","")
    d["Price"]=item.find("a",{"class":"listing-price"}).text.replace("\n","").replace(" ","")
    d["City"]=item.find("div",{"class":"property-city"}).text.replace("\n","").replace(" ","")
    try:
        d["Beds"]=item.find("div",{"class":"property-beds"}).find("b").text
    except:
        d["Beds"]=None
    try:
        d["Baths"]=item.find("div",{"class":"property-baths"}).text.replace("\n","")
    except:
         d["Baths"]=None
    try:
        d["Half Baths"]=item.find("div",{"class":"property-half-baths"}).text.replace("\n","")
    except:
        d["Half Baths"]=None
    try:
        d["Area"]=item.find("div",{"class":"property-sqft"}).text.replace("\n","")
    except:
        d["Area"]=None
    l.append(d)

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#                                               Address       Price  \
# 0                  15851 Stevens Canyon Rd        ...    $215,000
# 1                  10391 Castine Ave              ...  $2,798,000
# 2                  10403 Denison Ave              ...  $2,399,000
# 3                  21590 Grand Ave                ...  $1,500,000
# 4                  10439 Mary Ave                 ...  $1,236,788
# 5                  20684 Celeste Cir              ...    $799,000
# 6                  10163 Danube Dr                ...  $1,088,000
# 7                  23800 Amapolo Ct V6            ...  $1,800,000
# 8                  10280 Park Green Lane #828     ...  $1,850,000
# 9                  19161 Tilson AVE               ...  $5,198,000
# 10                 1322-1323 Flower CT            ...  $4,299,888
# 11                 10110 Westminster CT           ...  $3,899,888
# 12                 13119 Montebello RD            ...  $3,500,000
# 13                 13360 Montebello RD            ...  $3,295,000
# 14                 22047 Clearcreek CT            ...  $2,935,000
# 15                 931 Miller AVE                 ...  $2,499,000
# 16                 931 Miller AVE                 ...  $2,499,000
# 17                 20602 Murano CIR               ...  $2,098,000
# 18                 22040 Regnart RD               ...  $1,750,000
# 19                 11041 Stevens Canyon RD        ...  $1,699,999
#
#                 City  Beds             Baths            Half Baths  \
# 0   CupertinoCA95014  None              None                  None
# 1   CupertinoCA95014  None  2 baths                           None
# 2   CupertinoCA95014  None  2 baths                           None
# 3   CupertinoCA95014  None  2 baths                           None
# 4   CupertinoCA95014  None  2 baths           1 half bath
# 5   CupertinoCA95014  None   1 bath                           None
# 6   CupertinoCA95014  None  2 baths                           None
# 7   CupertinoCA95014  None  2 baths                           None
# 8   CupertinoCA95014  None  3 baths           1 half bath
# 9   CupertinoCA95014  None  4 baths           1 half bath
# 10  CupertinoCA95014  None  6 baths                           None
# 11  CupertinoCA95014  None  3 baths           1 half bath
# 12  CupertinoCA95014  None  2 baths                           None
# 13  CupertinoCA95014  None  4 baths                           None
# 14  CupertinoCA95014  None  2 baths                           None
# 15  CupertinoCA95014  None              None                  None
# 16  CupertinoCA95014  None  4 baths                           None
# 17  CupertinoCA95014  None  4 baths                           None
# 18  CupertinoCA95014  None              None                  None
# 19  CupertinoCA95014  None   1 bath                           None
#
#                      Area
# 0                    None
# 1   1,890 sq. ft
# 2   1,408 sq. ft
# 3   1,692 sq. ft
# 4   1,216 sq. ft
# 5     871 sq. ft
# 6   1,154 sq. ft
# 7   1,303 sq. ft
# 8   2,058 sq. ft
# 9   4,138 sq. ft
# 10  3,083 sq. ft
# 11  3,217 sq. ft
# 12  1,100 sq. ft
# 13  3,196 sq. ft
# 14  1,661 sq. ft
# 15  2,046 sq. ft
# 16  2,046 sq. ft
# 17  2,036 sq. ft
# 18                   None
# 19    900 sq. ft

# %%
df.to_csv("Output.csv")
